# %%
import pandas as pd
import json

# %%
with open('D:/056.의약품, 화장품 패키징 OCR 데이터/01.데이터/1. Training/라벨링데이터/TL1/result\medicine/annotations/medicine_00001.json') as f :
    js = json.loads(f.read())

# %%
df = pd.DataFrame(js)

# %%
images = df["images"][0]
image_df = pd.DataFrame(images.values())
image_df.index = images.keys()
image_df
# Out:
#                                            0
# identifier                    medicine_00001
# name                      medicine_00001.jpg
# type                                     jpg
# width                                   2694
# height                                  2078
# data_captured            2021:09:19 14:02:34
# shutter_speed                            320
# f_stop                                   1.8
# gps
# age                                       53
# gender                                female
# writer_num             psjspaspa96@naver.com
# shooting_env                              실내
# dust                                      없음
# class                                    의약품
# product_name      레복사신점안액0.5%(레보플록사신수화물) 5ml
# product_category                   의약품_전문의약품

# %%
annotations = df["annotations"][0]
annotations_df = pd.DataFrame(annotations.values())
annotations_df.index = annotations.keys()
annotations_df
# Out:
#                                                           0  \
# polygons  {'id': '005cc8c0-ca7e-44b2-8719-66f5a1878c9a',...
# bbox      {'id': '005cc8c0-ca7e-44b2-8719-66f5a1878c9a',...
#
#                                                           1  \
# polygons  {'id': '7290b057-676c-462b-bfa1-409b0aae2211',...
# bbox      {'id': '7290b057-676c-462b-bfa1-409b0aae2211',...
#
#                                                           2  \
# polygons  {'id': 'eb6bbc8a-57da-436f-a526-0fe3655addee',...
# bbox      {'id': 'eb6bbc8a-57da-436f-a526-0fe3655addee',...
#
#                                                           3  \
# polygons  {'id': 'b8cc944b-e761-4dbd-a960-d133fa5ca5f0',...
# bbox      {'id': 'b8cc944b-e761-4dbd-a960-d133fa5ca5f0',...
#
#                                                           4  \
# polygons  {'id': '9fe2943b-1a93-468d-9360-67bd2d59da67',...
# bbox      {'id': '9fe2943b-1a93-468d-9360-67bd2d59da67',...
#
# ...

# %%
annotations_df[0].bbox cv
# Out:
# {'id': '005cc8c0-ca7e-44b2-8719-66f5a1878c9a',
#  'x': 618.8790117005273,
#  'y': 223.058390996303,
#  'width': 1728.205525300914,
#  'height': 180.14412636688292}

# %%
# Out:
#                                            0
# identifier                    medicine_00001
# name                      medicine_00001.jpg
# type                                     jpg
# width                                   2694
# height                                  2078
# data_captured            2021:09:19 14:02:34
# shutter_speed                            320
# f_stop                                   1.8
# gps
# age                                       53
# gender                                female
# writer_num             psjspaspa96@naver.com
# shooting_env                              실내
# dust                                      없음
# class                                    의약품
# product_name      레복사신점안액0.5%(레보플록사신수화물) 5ml
# product_category                   의약품_전문의약품
